# %%
import matplotlib.pyplot as plt
import numpy as np

xaxis=np.array(["c","c++","java","python"])

yaxis=np.array([45,65,88,93])
z=np.array([30,40,50,60])
plt.xlabel("Programmings",fontsize=15)
plt.ylabel("Rates")
plt.bar(xaxis,yaxis,color='r',width=0.2,edgecolor='r',linewidth=1,label="shivay")
plt.bar(xaxis,z,color='g',width=0.3,edgecolor='r',linewidth=1,label="shivay2")
plt.legend()
plt.title("Testing123")
plt.show()
