# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
arr=np.random.rand(20)

# %%
arr
# Out:
# array([0.54932128, 0.24299683, 0.43533443, 0.42195713, 0.49039874,
#        0.67010081, 0.9217061 , 0.43808765, 0.94997044, 0.58033814,
#        0.4402866 , 0.16012293, 0.34545492, 0.41081256, 0.25033665,
#        0.71616899, 0.27313123, 0.34072171, 0.01504961, 0.97739035])

# %%
style.use('ggplot')
plt.plot(arr,'b',label="line_one",linewidth=1)
plt.xlabel('range')
plt.ylabel('Number')
plt.title('First Plot')
plt.legend()
plt.show()
